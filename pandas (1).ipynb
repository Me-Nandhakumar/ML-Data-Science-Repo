# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
filepath = r"C:\Users\nandh\Downloads\Amazon Sale Report.xlsx"
d = pd.read_excel(filepath)
d
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128971  406-6001380-7673107  05-31-22                       Shipped
# 128972  402-9551604-7544318  05-31-22                       Shipped
# 128973  407-9547469-3152358  05-31-22                       Shipped
# 128974  402-6184140-0545956  05-31-22                       Shipped
# 128975  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
df = d.drop(d.index[1000:128975])   # index 10 to 20
print("\nAfter deleting rows 10 to 20:")
print(df)
# Out:
# After deleting rows 10 to 20:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 996     404-6513417-3841113  04-30-22                       Shipped
# 997     408-7484954-7860326  04-30-22                       Shipped
# 998     408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 999     408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 128975  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# ...

# %%
df.shape
# Out:
# (1001, 20)

# %%
d=df.to_excel(r"C:\Users\nandh\Downloads\Amazon Sale.xlsx",index=False)
d
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d=df.to_excel(r"C:\Users\nandh\Downloads\Amazon Sale.xlsx",index=False)
#       2 d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
s=pd.read_excel(r"C:\Users\nandh\Downloads\Amazon Sale.xlsx")
s
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
s.head(10)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
# 5  404-1490984-4578765  04-30-22                       Shipped     Amazon
# 6  408-5748499-6859555  04-30-22                       Shipped     Amazon
# 7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer   Merchant
# 8  407-5443024-5233168  04-30-22                     Cancelled     Amazon
# 9  402-4393761-0311520  04-30-22                       Shipped     Amazon
#
#   Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# 0     Amazon.in           Standard   T-shirt    S     On the Way    0
# ...

# %%
s.tail(10)
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 991   171-6613108-2363511  04-30-22                       Shipped     Amazon
# 992   406-5961574-4441901  04-30-22                       Shipped     Amazon
# 993   404-9326488-7546742  04-30-22                       Shipped     Amazon
# 994   403-1691463-7067522  04-30-22                       Shipped     Amazon
# 995   171-1293566-4097166  04-30-22                       Shipped     Amazon
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
#      Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            1001 non-null   object
#  1   Date                1001 non-null   object
#  2   Status              1001 non-null   object
#  3   Fulfilment          1001 non-null   object
#  4   Sales Channel       1001 non-null   object
#  5   ship-service-level  1001 non-null   object
#  6   Category            1001 non-null   object
#  7   Size                1001 non-null   object
#  8   Courier Status      1001 non-null   object
#  9   Qty                 1001 non-null   int64
#  10  currency            929 non-null    object
#  11  Amount              929 non-null    object
#  12  ship-city           1001 non-null   object
#  13  ship-state          1001 non-null   object
#  14  ship-postal-code    1001 non-null   int64
# ...

# %%
s.describe()
# Out:
#                Qty  ship-postal-code  New  PendingS
# count  1001.000000       1001.000000  0.0       0.0
# mean      0.912088     476051.565435  NaN       NaN
# std       0.542461     195528.538101  NaN       NaN
# min       0.000000     110007.000000  NaN       NaN
# 25%       1.000000     383001.000000  NaN       NaN
# 50%       1.000000     500070.000000  NaN       NaN
# 75%       1.000000     600078.000000  NaN       NaN
# max      15.000000     855102.000000  NaN       NaN

# %%
s.shape
# Out:
# (1001, 20)

# %%
s.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
s.rename(columns={'Qty':'Quality '})
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
s['ship-country'] = s['ship-country'].replace("IN", "INDIA")
s
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
s["Amount"]=s["Amount"].str.replace(r"[?]"," ",regex=True)

# %%
s
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
s["Status"]=s["Status"].replace("Cancelled","Cancel")
s
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                        Cancel   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                        Cancel   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
df.drop(columns=['New'])
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 996     404-6513417-3841113  04-30-22                       Shipped
# 997     408-7484954-7860326  04-30-22                       Shipped
# 998     408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 999     408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 128975  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
s.rename(columns={"PendingS":"Pendings"})
# Out:
#                  Order ID      Date                        Status Fulfilment  \
# 0     405-8078784-5731545  04-30-22                        Cancel   Merchant
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2     404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3     403-9615377-8133951  04-30-22                        Cancel   Merchant
# 4     407-1069790-7240320  04-30-22                       Shipped     Amazon
# ...                   ...       ...                           ...        ...
# 996   404-6513417-3841113  04-30-22                       Shipped     Amazon
# 997   408-7484954-7860326  04-30-22                       Shipped     Amazon
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer   Merchant
# 1000  408-7436540-8728312  05-31-22                       Shipped     Amazon
#
# ...

# %%
import pandas as pd
d=pd.read_excel(r"C:\Users\nandh\Downloads\Amazon Sale.xlsx")
d
x=d[["Order ID"]]
x
d.iloc[0]
d.iloc[:,:3]#row,columns
# Out:
#                  Order ID      Date                        Status
# 0     405-8078784-5731545  04-30-22                     Cancelled
# 1     171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2     404-0687676-7273146  04-30-22                       Shipped
# 3     403-9615377-8133951  04-30-22                     Cancelled
# 4     407-1069790-7240320  04-30-22                       Shipped
# ...                   ...       ...                           ...
# 996   404-6513417-3841113  04-30-22                       Shipped
# 997   408-7484954-7860326  04-30-22                       Shipped
# 998   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 999   408-0027611-3047556  04-30-22  Shipped - Delivered to Buyer
# 1000  408-7436540-8728312  05-31-22                       Shipped
#
# [1001 rows x 3 columns]

# %%
from sklearn.model_selection import GridSearchCV

params = {
    "model__C": [0.1, 1, 10],
    "model__kernel": ["linear", "rbf"]
}

grid = GridSearchCV(pipe, params, cv=5)
grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Best Params: {'model__C': 0.1, 'model__kernel': 'linear'}
# Best Score: 0.9583333333333334
